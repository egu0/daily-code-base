# %%
from dotenv import load_dotenv
import os
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv()

client = OpenAI(
    base_url="https://api.deepseek.com", api_key=os.getenv("DEEPSEEK_KEY")
)
MODEL = "deepseek-v4-flash"

# %% [markdown]
# ## Agent 01

# %%
def agent01(prompt):
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt},
    ]
    resp = client.chat.completions.create(
        model=MODEL,
        messages=messages
    )
    msg = resp.choices[0].message
    return msg.content

# %%
md = agent01("AI 时代，高考对人生而言意味着什么")
display(Markdown(md))
# Out:
# AI时代，高考的意义正在被重新定义，但它依然是人生中一个至关重要的节点。让我从几个层面来探讨。
#
# **1. 公平竞争的“压舱石”**
# 在AI加速信息差、资源分配可能更不均的背景下，高考依然是中国社会最透明、最可量化的选拔机制。它不问你出身、不看你家是否有AI设备，只凭同一张卷子和努力程度。对于千万普通家庭的孩子，高考仍然是打破阶层壁垒、获得优质教育资源和更大人生选择权的核心通道。
#
# **2. 对人“底层能力”的淬炼**
# AI可以瞬间输出答案，但高考考察的不仅是知识记忆——它考验的是：
# - **延迟满足的耐力**：三年如一日的自律，这是AI无法替代的意志力。
# - **复杂问题的拆解能力**：数学压轴题的逻辑链、语文作文的立意结构，都在训练人如何从混沌中理出框架。
# - **抗压与情绪调节**：大考前的焦虑应对，是未来面对AI冲击下的职场不确定性时的重要心理预演。
# 这些能力在AI时代反而更稀缺、更宝贵。
#
# **3. 避免“工具化”的警醒**
# AI擅长模仿和优化，但高考的命题趋势正在变化：更强调批判性思维、开放性问题、真实情境解决能力。如果只把高考当作刷题闯关，可能会在AI时代沦为“高级计算器”。真正的价值在于——通过备考，你学会如何学习、如何质疑、如何构建自己的知识体系。这是人类区别于AI的核心。
#
# **4. 人生的“时间锚点”**
# 高考是18岁左右一个清晰的目标。在AI带来的信息爆炸和路径多元化中，许多人反而迷失方向。高考提供了一个相对确定的奋斗周期：不论未来你选择AI相关专业还是人文艺术，这个全力以赴的过程本身就是成长的缩影。它教会你如何为一件重要的事长期专注，这种体验是任何算法都无法给你的。
#
# **5. 不是终点，而是新起点**
# AI时代的知识更迭极快，高考分数的影响力会随时间递减。但你在备考中建立的学习习惯、抗挫能力、时间管理，以及通过高考进入的大学平台，决定了你后续能否更快地学习AI、驾驭AI。**高考的意义不在于让你“赢在起跑线”，而在于让你拥有选择“跑道”的资格**——是成为技术的使用者、创造者，还是被替代者。
#
# **总结**
# 在AI时代，高考对人生而言，不是“一考定终身”的终极审判，而是一次**系统性的成人礼**：它检验你过去十八年的积淀，锻炼你面对未来不确定性的核心素质，并为你提供一个相对公平的向上通道。你之后的人生，取决于如何利用高考所赋予的认知基础和毅力，去与AI共舞，而不是被它淹没。
