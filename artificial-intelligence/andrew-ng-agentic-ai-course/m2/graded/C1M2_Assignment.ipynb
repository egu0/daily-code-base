# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv
import utils

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: # @KEEP
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = None # @KEEP

    ### START OMIT BLOCK
    prompt = f"""
    Write a well-structured draft essay in response to the following topic.
    The draft should include an introduction, body, and conclusion.

    topic:
    {topic}
    """
    ### END OMIT BLOCK
    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
user_question = "Should people be encouraged to eat less meat?"
utils.print_html(user_question, title="Topic")

draft_v1 = generate_draft(user_question)
utils.print_html(draft_v1, title="Draft")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Only affects INSIDE the card */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Topic</div><pre><code>Should people be encouraged to eat less meat?</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Only affects INSIDE the card */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Draft</div><pre><code>**Title: Encouraging Reduced Meat Consumption: A Path Towards Sustainability and Health**
#
# **Introduction**
#
# In recent years, the conversation around food consumption has increasingly turned towards the ethical, environmental, and health implications of meat-heavy diets. While meat has traditionally been a staple in many cultures worldwide, a growing body of research suggests that encouraging people to eat less meat could have significant benefits. These include positive impacts on personal health, environmental sustainability, and animal welfare. This essay will explore these benefits and argue that people should indeed be encouraged to consume less meat for the betterment of both individual well-being and the planet.
#
# **Body**
#
# Firstly, reducing meat consumption can lead to substantial health benefits. Numerous studies have highlighted the links between high meat intake and preventable diseases such as heart disease, type 2 diabetes, and certain types of cancer. Red meats and processed meats, in particular, have been identified as significant contributors to these conditions due to their high levels of saturated fats and preservatives. By eating less meat, individuals may reduce their risk of developing such illnesses while also lowering their cholesterol and blood pressure levels. Furthermore, diets rich in plant-based foods such as fruits, vegetables, whole grains, and legumes can provide essential nutrients and fiber, promoting overall health and longevity.
#
# Secondly, the environmental impact of meat production is immense and well-documented. The livestock industry is one of the largest contributors to greenhouse gas emissions, deforestation, and biodiversity loss, thereby exacerbating climate change and environmental degradation. Producing meat requires vast amounts of water and land resources, often leading to unsustainable agricultural practices. Encouraging people to eat less meat can significantly reduce these environmental burdens. A widespread shift toward plant-based diets could decrease global agricultural emissions by a considerable margin, help conserve water resources, and slow down the destruction of vital ecosystems, fostering a more sustainable future.
#
# Finally, ethical considerations surrounding animal welfare provide another compelling reason to encourage reduced meat consumption. Factory farming, a prevalent method used to meet the high demand for meat, often results in poor living conditions for animals, raising concerns about cruelty and inhumane treatment. By choosing to consume less meat, individuals can reduce their support for these practices and contribute to a shift toward more ethical and sustainable food systems. Increased demand for plant-based alternatives and responsibly sourced meats can incentivize improvements in livestock welfare and encourage more humane farming practices.
#
# **Conclusion**
#
# In conclusion, encouraging people to eat less meat is a crucial step toward promoting a healthier population and a more sustainable planet. The benefits of reduced meat consumption are far-reaching, impacting personal health outcomes, environmental preservation, and animal welfare. While dietary changes are deeply personal and often influenced by cultural factors, gradual shifts toward plant-based eating can be fostered through education, policy changes, and increased availability of alternatives. By collectively embracing such changes, societies can ensure a healthier future for current and coming generations, alongside a more balanced and ethical relationship with the natural world.</code></pre></div>

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = None # @KEEP

    ### START OMIT BLOCK
    prompt = f"""
    Reflect critically on the following draft essay.
    Identify areas for improvement in structure, clarity, argument strength, or style.
    Provide constructive feedback in paragraph form.

    Draft:
    {draft}
    """
    ### END OMIT BLOCK
    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
feedback = reflect_on_draft(draft_v1)

utils.print_html(feedback, title="Feedback")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Only affects INSIDE the card */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Feedback</div><pre><code>The essay offers a clear and well-intentioned overview of why reduced meat consumption benefits health, the environment, and animal welfare, but it could be strengthened by tightening its overall structure and sharpening its argumentative focus. The introduction clearly sets out the stakes but might benefit from a more engaging hook—perhaps a striking statistic or anecdote—to draw readers in before summarizing the core argument. In the body paragraphs, the transitions between health, environmental, and ethical considerations feel a bit mechanical; weaving these threads together through comparative examples (for instance, by showing how a single dietary shift can yield both personal health and climate benefits) would create a more cohesive narrative. Some of the evidence, especially regarding disease risk and emissions data, could be bolstered with specific studies or figures to lend greater credibility—right now the claims, though plausible, remain somewhat general. The section on animal welfare is persuasive in tone but would gain force by acknowledging common counterarguments, such as the cultural importance of meat in certain regions, and then gently refuting them. Finally, the conclusion appropriately calls for education and policy change but might close with a more memorable call to action or vision of what a plant-forward society looks like in practice. Stylistically, varying sentence length and substituting a few of the more familiar phrases (“promoting a healthier population,” “more sustainable future”) with fresh language could enliven the prose and sustain reader interest throughout. By tightening its structure, grounding its claims in specific data, and sharpening its stylistic voice, the essay will move from a solid overview to a compelling, memorable argument for reduced meat consumption.</code></pre></div>

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = None # @KEEP

    ### START OMIT BLOCK

    prompt = f"""
    Revise the following essay draft using the feedback provided.
    Make improvements in clarity, coherence, argumentation, and flow.
    Return only the improved essay.

    Original Draft:
    {original_draft}

    Feedback:
    {reflection}
    """
    ### END OMIT BLOCK
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model, # @OMIT
        messages=[{"role": "user", "content": prompt}], # @OMIT
        temperature=1.0, # @OMIT
    ) # @OMIT

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
draft_v2 = revise_draft(draft_v1, feedback)

utils.print_html(draft_v2, title="Revised Draft based on feedback")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Only affects INSIDE the card */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Revised Draft based on feedback</div><pre><code>**Title: A Sustainable Bite: The Case for Reducing Meat Consumption**
#
# **Introduction**
#
# Imagine a world where every bite we take contributes not only to our health but also to the planet’s well-being. Surprising as it may seem, reducing meat consumption might be the key to such a future. As discussions around food practices intensify, the ethical, environmental, and health implications of meat-rich diets surface as critical concerns. While meat holds significant cultural value worldwide, mounting research indicates that consuming less meat delivers substantial benefits. This essay explores those advantages, positing that reducing meat intake benefits individual health, environmental sustainability, and animal welfare. The following sections make a case for why encouraging such dietary shifts is essential for humanity&#x27;s future.
#
# **Health Benefits**
#
# Foremost, cutting back on meat intake undeniably fosters better health. Evidence consistently ties high meat consumption, especially red and processed meats, to preventable illnesses like heart disease, type 2 diabetes, and certain cancers. These foods often carry high levels of saturated fats and preservatives, elevating health risks. By reducing meat intake, individuals lower their chances of encountering these diseases, as well as reduce cholesterol and blood pressure levels. Juxtapose this with diets rich in plant-based foods: fruits, vegetables, whole grains, and legumes offer essential nutrients and fibers that enhance overall well-being and longevity. Thus, a shift toward plant-forward diets can yield immense, multidimensional health advantages.
#
# **Environmental Impact**
#
# Simultaneously, the environmental benefits of reduced meat consumption are profound. The livestock industry is a leading source of greenhouse gas emissions, deforestation, and biodiversity loss, significantly driving climate change. Meat production demands vast water and land resources, perpetuating unsustainable agricultural practices. A collective move towards plant-based diets could sharply cut global agricultural emissions, conserve precious water, and preserve vital ecosystems, presenting a compelling pathway to a sustainable future. Such a shift not only benefits the climate but also ensures natural resources for future generations, proving that healthful eating serves the environment too.
#
# **Ethical Considerations**
#
# Ethical considerations further bolster the case for consuming less meat. Factory farming, prevalent in meeting meat demands, subjects animals to deplorable living conditions, raising issues of cruelty and inhumane treatment. By choosing plant-based or responsibly sourced alternatives, consumers can undermine these practices. Addressing common counterarguments, such as the cultural significance of meat, reveals that dietary customs evolve over time. With increased availability of diverse plant-based foods, cultures can preserve their heritage while embracing humane and sustainable practices. Supporting ethical treatment of animals aligns with broader societal values and augments a holistic approach to food consumption.
#
# **Conclusion**
#
# Encouraging reduced meat consumption stands as a pivotal action toward shaping a healthier populace and a sustainable world. The intersections of health benefits, environmental preservation, and ethical reform make a compelling case for dietary shifts. While personal and cultural bonds with food run deep, gradual moves toward plant-based eating can be nurtured through education, policy reform, and accessible alternatives. As societies embrace these changes, they pave the way for a future where our food choices reflect a balanced, compassionate, and sustainable relationship with the Earth. Let us envision vibrant markets flourishing with plant-centric offerings, thriving ecosystems supporting diverse life forms, and communities enjoying enriched, holistic health—a transformational journey initiated by the simple choice to eat less meat.</code></pre></div>
